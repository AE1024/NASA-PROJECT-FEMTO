# %%
import polars as pl

splits = {
    "train": "features_train.parquet",
    "validation": "features_val.parquet",
    "test": "features_test.parquet",
}
df = pl.read_parquet(
    "hf://datasets/Amgharr/FEMTO-ST_DATASET/" + splits["train"]
)
# Out:
# Running cells with 'NASA_Project (3.13.12) (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/elmaz/AIProject/NASA_Project/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
